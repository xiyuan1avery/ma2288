# %% [markdown]
# <a href="https://colab.research.google.com/github/xiyuan1avery/ma2288/blob/main/notebooks/01_environment_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, NextLat experiment!")
# Out:
# Hello, NextLat experiment!

# %%
import torch

print("PyTorch version:", torch.__version__)
print("GPU available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected. Please check the Colab runtime settings.")
# Out:
# PyTorch version: 2.11.0+cu128
# GPU available: True
# GPU name: Tesla T4
